# %% [markdown]
# ## Import

# %%
import numpy as np
import scipy.integrate as integ
import scipy.interpolate as i2
import matplotlib.pyplot as plt
plt.rcParams.update(plt.rcParamsDefault)
from astropy import units as u
from astropy import constants as c
# import cmath as cm
from shooting import *
import shootingres as shr
import shooting as sho

import scipy.optimize as o
try:
    import cPickle as pickle
except ImportError:
    import pickle

import pandas as pd 
# import ray
from scipy.integrate import cumtrapz
import seaborn as sns
sns.set_theme()
sns.set_style("white")
sns.set_style("ticks")
sns.set_style("ticks",{'axes.grid' : True})
import scienceplots
plt.style.use('science')

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
from matplotlib.patches import Rectangle
f = 16

# %%
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 1.5
# plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'font.size': 12})
# plt.rcParams.update({'axes.labelsize': 14})
plt.rcParams.update({'axes.labelsize': 12})

plt.rcParams.update({'xtick.labelsize': 12, 'ytick.labelsize': 12})

# %%
## SET CONSTANTS
rho = (1.0*10**19) * (2.0*1.6725*10**(-27))
mu_0 = 1.2566*10**(-6)

# Define Normalizations
r1 = 0.1

## Define OMEGA0:
bb = 10000
v0 = bb/np.sqrt(r1)
Omega0 = v0/r1

# %% [markdown]
# ## MCI Hain

# %%
def shoot_hain_v3(w, eta, Pm, qr, qrp, qi, qip,  k=np.pi/2, m=1, B0=0, Bz = 0, keplerian=True, cc=1, r2=5, max=500, q=1/2, W = 0, Wp = 0, Wpp = 0, ai = 0):
    ## DIFF IS INCLUDES IMAG
    y0 = [0.,1.+1.j]
    y = i.solve_ivp(shoot_setup_hain_v2, [1,r2**2], y0, args=(w,eta, Pm, qr, qrp, qi, qip, m,k,B0,Bz, keplerian,cc, q, W, Wp, Wpp, ai), max_step=24./(max/r2))
    r = np.sqrt(y.t)
    u = y.y[0]
    return ((u/r)[-1])

### REDONE DERIVATION
def shoot_setup_hain_v2(x, y, w, elecd, Pm, k2rs, k2rps, k2is, k2ips, m, kz=np.pi/4, B0=60, Bz=12.967, keplerian=True, cc=1, q=1/2, W_f = 0, Wp_f = 0, Wpp_f = 0, ai = 0):
    mu_0 = 1.2566*10**(-6)
     ### PM = 1
    r = np.sqrt(x)
    # print(elecd)
    # print(k2rs)
    # print(k2is)
    k2 = k2rs(r) + 1j*k2is(r)
    k2p = k2rps(r) + 1j*k2ips(r)
    vp1 = 1
    if keplerian == True:
        vp = vp1/(x**(1/4))
        W = vp/r
        Wp = -3/4*vp1/(x**(7/4)) * 2*r
        Wpp = 21/16*vp1/(x**(11/4)) * 4 * r**2
    elif keplerian == 'khalzov':
        W = vp1/x
        Wp = -vp1/x**2
    elif keplerian == 'rigid':
        W = vp1
        Wp = 0
    elif keplerian == False:
        vp = vp1/(x**(q/2))
        W = vp/r
        Wp = (-1*(q+1)/2)*(W/x)
    elif keplerian == 'saturated':
        # print('ahh')
        A0 = 1.4923889E-02
        A1 = -1.0114824E-01
        A2 = 8.5753488E-02
        A3 = -2.8021088E-02
        A4 = -4.7882189E-01
        A5 = 1.0877462E-01
        A6 = 6.7857446E+00
        A7 = -5.0846913E+00
        A8 = -4.3114342E+01
        A9 = 5.2943846E+01
        A10 = 1.2219068E+02
        A11 = -1.9185099E+02
        A12 = -1.7535573E+02
        A13 = 3.4808679E+02
        A14 = 1.1975807E+02
        A15 = -3.4500839E+02
        A16 =  -1.4844420E+01
        A17 = 1.7930272E+02
        A18 = -2.5033736E+01
        ###  0.08875 + 0.91125/r^2 
        W = 0.08875 + 0.91125/r**2 + A0 + A1*(r-2) + A2*(r-2)**2+A3*(r-2)**3 + A4*(r-2)**4 + A5*(r-2)**5 + A6*(r-2)**6 + A7*(r-2)**7 + A8*(r-2)**8 + A9*(r-2)**9 + A10*(r-2)**10 + A11*(r-2)**11 + A12*(r-2)**12 + A13*(r-2)**13 + A14*(r-2)**14 + A15*(r-2)**15 + A16*(r-2)**16 + A17*(r-2)**17 + A18*(r-2)**18 - ( A1 + A3 + A5 + A7 + A9 + A11 + A13 + A15 + A17 )*(r-2)**19 - ( A0 + A2 + A4 + A6 + A8 + A10 + A12 + A14 + A16 + A18 )*(r-2)**20
        Wp = - 2 * 0.91125/r**3  + A1 + 2 * A2*(r-2) + 3 * A3*(r-2)**2 + 4 * A4*(r-2)**3 + 5 * A5*(r-2)**4 + 6 * A6*(r-2)**5 + 7 * A7*(r-2)**6 + 8 * A8*(r-2)**7 + 9 * A9*(r-2)**8 + 10 * A10*(r-2)**9 + 11 * A11*(r-2)**10 + 12 * A12*(r-2)**11 + 13 * A13*(r-2)**12 + 14 * A14*(r-2)**13 + 15 * A15*(r-2)**14 + 16 * A16*(r-2)**15 + 17 * A17*(r-2)**16 + 18 * A18*(r-2)**17 - 19 * ( A1 + A3 + A5 + A7 + A9 + A11 + A13 + A15 + A17 )*(r-2)**18 - 20 * ( A0 + A2 + A4 + A6 + A8 + A10 + A12 + A14 + A16 + A18 )*(r-2)**19
        Wpp = 3 * 2 * 0.91125/r**4  + 2 * A2 + 3 * 2 * A3*(r-2) + 4 * 3 * A4*(r-2)**2 + 5 * 4 * A5*(r-2)**3 + 6 * 5 * A6*(r-2)**4 + 7 * 6 * A7*(r-2)**5 + 8 * 7 * A8*(r-2)**6 + 9 * 8 * A9*(r-2)**7 + 10 * 9  * A10*(r-2)**8 + 11 * 10 * A11*(r-2)**9 + 12 * 11 * A12*(r-2)**10 + 13 * 12 * A13*(r-2)**11 + 14 * 13 * A14*(r-2)**12 + 15 * 14 * A15*(r-2)**13 + 16 * 15 * A16*(r-2)**14 + 17 * 16 * A17*(r-2)**15 + 18 * 17 * A18*(r-2)**16 - 19 * 18 * ( A1 + A3 + A5 + A7 + A9 + A11 + A13 + A15 + A17 )*(r-2)**17 - 20 * 19 * ( A0 + A2 + A4 + A6 + A8 + A10 + A12 + A14 + A16 + A18 )*(r-2)**18 
        
    elif keplerian == 'saturated2':
        W = W_f(r)
        Wp = Wp_f(r)
        Wpp = Wpp_f(r)
    elif keplerian == 'tanh':
        a = c = b = d = 1
        a = 0.6
        c = a
        d = 0.9
        W= d*np.tanh(-c*r+a)+b
        Wp = -c * d * (1/np.cosh(-c * r + a))**2
        Wpp = -2 * c**2 * d * np.tanh(-c * r + a)*(1/np.cosh(-c * r + a))**2
    elif keplerian == 'exp1':
        a = 1
        W = a*np.exp(1-r) + 1-a
        Wp = -a*np.exp(1-r)
        Wpp = a*np.exp(1-r)
    elif keplerian == 'exp2':
        a = 1
        W = a*r*np.exp(1-r) + (1-a)
        Wp = a*np.exp(1-r)*(1-r)
        Wpp = a*np.exp(1-r)*(r-2)
    elif keplerian == 'exp3':
        a = .75
        W = a*r*np.exp(1-r) + (1-a)
        Wp = a*np.exp(1-r)*(1-r)
        Wpp = a*np.exp(1-r)*(r-2)
    elif keplerian == 'expi':
        a = ai
        W = a*np.exp(1-r) + 1-a
        Wp = -a*np.exp(1-r)
        Wpp = a*np.exp(1-r)
    elif keplerian == 'con':
        W = 1
        Wp = 0
        Wpp = 0
    elif keplerian == 'tanhv5':
        a = c = b = d = 1
        a = 1
        c = a
        d = 0.77
        W= d*np.tanh(-c*r+a)+b
        Wp = -c * d * (1/np.cosh(-c * r + a))**2
        Wpp = -2 * c**2 * d * np.tanh(-c * r + a)*(1/np.cosh(-c * r + a))**2
    elif keplerian == 'q_prof':
        W = 1/r**q
        Wp = -q*1/r**(q+1)
        Wpp = (q+1)*q*1/r**(q+2)
    # Define Normalizations
    r1 = 0.1

    ## Define OMEGA0:
    bb = 10000
    v0 = bb/np.sqrt(r1)
    Omega0 = v0/r1

    vAp1 = B0/(r1*Omega0*np.sqrt(rho*mu_0)*10000)
    
    vAp = vAp1/r
    vAz = Bz / (r1*Omega0*np.sqrt(rho*mu_0)*10000)
    
    ### MODIFY w
    wA = (m/r)*vAp + kz*vAz
    wb = w-m*W
    wc = 2*vAp/r*cc
    
    wAp = -m*vAp1/x**2*2*r
    wcp = -2*vAp1/x**2*cc*2*r

    # elecd = elecd / (r1**2*Omega0)*2
    elecd = elecd / (r1**2*Omega0)
    nu = elecd*1

    ### Note this is k2p with respect to r.
    wbp = -m*Wp
    wbpp = -m*Wpp
    lnu = -1j*wb + nu*k2
    lnup = -1j*wbp + nu*k2p
    leta = -1j*wb + elecd*k2
    letap = -1j*wbp + elecd*k2p
    
    L = lnu + wA**2/(leta)
    Lp = lnup + 2*wA*wAp/leta - wA**2*letap/(leta**2)
    h2 = kz**2 + m**2/r**2
    h = np.sqrt(h2)
    hp = -1/h*(m**2/r**3)
    E = L**2 + L*r/leta * wc * (1j*wA*Wp/leta - 1/2*wcp) + 2*(W - 1j*1/2*wc*wA/leta)*(2*W + (1+wA**2/leta**2)*r*Wp - 1j*wA*wc/leta)
    f = 2*r**2*(leta*lnu + wA**2)/((kz**2*r**2+m**2))
    fp = 1/(kz**2*r**2+m**2) * (4*r*(leta*lnu + wA**2) +2*r**2*(letap*lnu+leta*lnup + 2*wA*wAp)) - 1/(kz**2*r**2+m**2)**2 * (4*kz**2*r**3*(lnu*leta + wA**2))
    s = (1j*m*(lnu - leta)/(h**2*r)*Wp)
    g_dr_num_undiff = ((leta - lnu) * r * Wp + 2*(W*leta - 1/2*wc*wA))
    g_dr_num_diff = (letap - lnup) * r * Wp + (leta - lnu)*(Wp + r*Wpp) + 2*(Wp*leta + W*letap - 1/2*wcp*wA - 1/2*wc*wAp)
    g_dr_denom_undiff = h**2*r**2
    g_dr_denom_diff = 2*h*hp*r**2 + 2*h**2*r
    g_dr_term = 1j*m*(g_dr_num_diff/g_dr_denom_undiff - g_dr_num_undiff*g_dr_denom_diff/g_dr_denom_undiff**2)

    g = g_dr_term + E*leta/(L*r) - (W - 1j*1/2*wc*wA/leta)*(2*m**2/(L*h**2*r**3))*((leta - lnu)*r*Wp + 2*(W*leta - 1j * 1/2*wA*wc))

    u, du = y

    ### REWRITE ALL TERMS
    f = leta*L/(h**2*r)
    fp = (letap*L + leta*Lp)/(h**2*r) - leta*L*(2*h*hp*r+h**2)/(h**2*r)**2

    u_coeff = 1/(-4*r)*-g
    du_coeff = -1/(4*r)*(2*(f+r*fp)) - s/(2)
    d2u_coeff = -r*f
    dudx = [du, (1/d2u_coeff)*(-du_coeff*du - u_coeff*u)]

    return dudx

# %% [markdown]
# ## Defining Sweep

# %%
r2 = 5
m = 1
kn = 1
kz = kn*np.pi/(4)

r = np.linspace(1, r2, 500)
q_mag = np.pi**2
q2r_sc = q_mag*1/r**2
q2rp_sc = q_mag*(-2/r**3)
q2rpp_sc = q_mag*(6/r**4)
q2i_sc = q_mag*np.zeros(len(r))
q2ip_sc = q_mag*np.zeros(len(r))
q2ipp_sc = q_mag*np.zeros(len(r))

ones_arr = np.ones(len(r)) 
k2 = (q2r_sc + 1j*q2i_sc) + m**2/r**2 + kz**2 * ones_arr
k2p = ((q2rp_sc + 1j*q2ip_sc) - 2 * m**2/r**3) ## just changed from d/dr
k2pp = ((q2rpp_sc + 1j*q2ipp_sc) + 6 * m**2/r**4) ## just changed from d/dr

k2r_curr = i2.CubicSpline(r, k2.real)
k2i_curr = i2.CubicSpline(r, k2.imag)
k2rp_curr = i2.CubicSpline(r, k2p.real)
k2ip_curr = i2.CubicSpline(r, k2p.imag)
k2rpp_curr = i2.CubicSpline(r, k2pp.real)
k2ipp_curr = i2.CubicSpline(r, k2pp.imag)

dt = 0.1/4
eta_arr = np.arange(0,200,dt)
r2_arr = np.arange(5,10, dt)
r2_arr_down = np.flip(np.arange(2,5+dt, dt))

VA_N_arr_up = np.arange(0.05,.7,0.01/4)

dq = 0.01/4
q_arr = np.arange(1/2, 2+dq, dq)
R_arr = np.zeros(len(q_arr))
v_arr = np.zeros(len(q_arr))
vp_arr = np.zeros(len(q_arr))
W_arr = np.zeros(len(q_arr))
for j in range(0, len(q_arr)):
        q = q_arr[j]
        W_exp= 1/r**q
        Wp_exp = -q/r**(q+1)
        Wpp_exp = (q+1)*q/r**(q+2)
        v = 1/r*(2*r*W_exp + r**2*Wp_exp)
        vp = -1/r**2*(2*r*W_exp + r**2*Wp_exp) + 1/r*(2*W_exp + 4*r*Wp_exp + r**2*Wpp_exp)
        R_exp = np.average(vp)/np.average(v)
        R_arr[j] = R_exp
        v_arr[j] = np.average(v)
        vp_arr[j] = np.average(vp)
        W_arr[j] = np.average(1/r**q)

# %%
plt.figure()
plt.plot(q_arr, np.abs(vp_arr)/np.abs(v_arr))
plt.show()

plt.figure()
plt.plot(q_arr, np.abs(vp_arr)/np.abs(W_arr))
plt.show()

plt.figure()
plt.plot(q_arr, np.abs(v_arr)/np.abs(W_arr))
plt.show()

# %% [markdown]
# ## Initial Modes

# %%
##### SET PARAMETERS #####
color_arr = ['#3F90DA', '#FFA90E', '#BD1F01', '#94A4A2', '#832DB6', '#A96B59', '#E76300', '#B9AC70', '#92DADD']

reso = 5000

r1 = 0.1
q = 1/2
type = 'MCI'
elecd = 0
eta = elecd
Pm = 1
m = 1
kn = 1
kz = kn*np.pi/(4)
VA_N = 0.2
Bz = VA_N* (r1*Omega0*np.sqrt(rho*mu_0)*10000)
B0 = 0

############## Kep
##### SET PARAMETERS #####
flow_type = 'q'

if(flow_type == 'q'):
    flow_select = 'q_prof'

## MCI 1k1
kn = 1
kz = kn*np.pi/(4)

VA_N = 0.2
Bz = VA_N* (r1*Omega0*np.sqrt(rho*mu_0)*10000)
guess = 0.5063998959160959+0.04296441637928505j

VA_N = 0.1
Bz = VA_N* (r1*Omega0*np.sqrt(rho*mu_0)*10000)
guess = 0.4766552870705516+0.024929356478651705j

VA_N = 0.05
Bz = VA_N* (r1*Omega0*np.sqrt(rho*mu_0)*10000)
guess = 0.46195228407362016+0.013061557756126075j


q = 1/2
Bz = VA_N* (r1*Omega0*np.sqrt(rho*mu_0)*10000)
result = o.root_scalar(shoot_hain_v3, method='secant', x0=guess*(1.00005+1e-6j), x1=guess*(0.99995-1e-6j), args=(eta, Pm, k2r_curr, k2rp_curr, k2i_curr, k2ip_curr, kz, m, B0, Bz, flow_select, 1, r2,reso, q, 1, 1, 1), maxiter=5000)
guess0 = result.root
print(result)

guess0 = result.root
y0 = [0.,(1.+1j)*1e-1]  
y = integ.solve_ivp(shoot_setup_hain_v2, [1,r2**2], y0, args=(guess,eta, Pm, k2r_curr, k2rp_curr, k2i_curr, k2ip_curr, m,kz,B0,Bz,flow_select, 1, q), max_step=24./reso)
r_p = np.sqrt(y.t)
u_p = y.y[0]

plt.figure()
plt.plot(r_p, (u_p/r_p).real)
plt.plot(r_p, (u_p/r_p).imag)
plt.show()
# Out:
#       converged: True
#            flag: converged
#  function_calls: 4
#      iterations: 3
#            root: (0.46195228407362193+0.013061557756124314j)
#          method: secant

# %% [markdown]
# ## All Modes

# %% [markdown]
# ### 1k1 MCI

# %%
##### SET PARAMETERS #####
color_arr = ['#3F90DA', '#FFA90E', '#BD1F01', '#94A4A2', '#832DB6', '#A96B59', '#E76300', '#B9AC70', '#92DADD']

reso = 2000

eta = 0
r1 = 0.1
q = 1/2
type = 'MCI'
Pm = 1
m = 1
kn = 1
kz = kn*np.pi/(4)
B0 = 0
r2 = 5
############## Kep
##### SET PARAMETERS #####
flow_type = 'q'

if(flow_type == 'q'):
    flow_select = 'q_prof'


complex_freqs_MCI_1k1_Kep_uu = np.zeros((len(VA_N_arr_up),len(q_arr)), dtype = 'complex')
complex_freqs_MCI_1k1_Kep_uu[0][0] = (.5063998959160959+0.04296441637928505j)
complex_freqs_MCI_1k1_Kep_uu[0][0] = (0.46195228407362016+0.013061557756126075j)

tol = 1E-6
for k in range(0,len(VA_N_arr_up)):
    for j in range(0,len(q_arr)):
        q = q_arr[j]
        Bz = VA_N_arr_up[k]* (r1*Omega0*np.sqrt(rho*mu_0)*10000)
        
        if(k == 0):
            if(j == 0):
                guess = complex_freqs_MCI_1k1_Kep_uu[k,j]
            else:
                guess = complex_freqs_MCI_1k1_Kep_uu[k,j-1]
        else:
            if(j == 0):
                guess = complex_freqs_MCI_1k1_Kep_uu[k-1,j]
            else:
                guess = complex_freqs_MCI_1k1_Kep_uu[k,j-1]

        if(np.abs(guess) == 0):
            guess = complex_freqs_MCI_1k1_Kep_uu[k,j-2]
        if(np.abs(guess) == 0):
            guess = complex_freqs_MCI_1k1_Kep_uu[k-1,j-1]
            
        result = o.root_scalar(shoot_hain_v3, method='secant', x0=guess*(1.00005+1e-6j), x1=guess*(0.99995-1e-6j), args=(eta, Pm, k2r_curr, k2rp_curr, k2i_curr, k2ip_curr, kz, m, B0, Bz, flow_select, 1, r2,reso, q, 1, 1, 1), maxiter=5000)
        if(result.converged == True):
            complex_freqs_MCI_1k1_Kep_uu[k,j] = result.root
        if(k == 0):
            if(j < 10):
                print(result)
        if(np.abs(np.imag(result.root)) < tol):
            break
        if(np.imag(result.root) < 0):
            guess = np.conjugate(result.root)
            result = o.root_scalar(shoot_hain_v3, method='secant', x0=guess*(1.00005+1e-6j), x1=guess*(0.99995-1e-6j), args=(eta, Pm, k2r_curr, k2rp_curr, k2i_curr, k2ip_curr, kz, m, B0, Bz, flow_select, 1, r2,reso, q, 1, 1, 1), maxiter=5000)
            if(result.converged == True):
                complex_freqs_MCI_1k1_Kep_uu[k,j] = result.root
    if(k % 10 == 0):
        print(f'{k}/{len(VA_N_arr_up)}')
# Out:
#       converged: True
#            flag: converged
#  function_calls: 4
#      iterations: 3
#            root: (0.46195228407394157+0.013061557755962641j)
#       converged: True
#            flag: converged
#  function_calls: 6
#      iterations: 5
#            root: (0.460199831847864+0.013094989768828351j)
#       converged: True
#            flag: converged
#  function_calls: 6
#      iterations: 5
#            root: (0.4584545436405795+0.013128338102218579j)
#       converged: True
#            flag: converged
#  function_calls: 6
#      iterations: 5
#            root: (0.45671639113944745+0.01316160327497821j)
#       converged: True
#            flag: converged
#  function_calls: 6
#      iterations: 5
#            root: (0.45498534614057445+0.013194785798096652j)
#       converged: True
#            flag: converged
#  function_calls: 6
#      iterations: 5
#            root: (0.45326138054846304+0.013227886174592777j)
#       converged: True
#            flag: converged
#  function_calls: 6
#      iterations: 5
#            root: (0.45154446637566864+0.013260904899633363j)
#       converged: True
#            flag: converged
#  function_calls: 6
#      iterations: 5
#            root: (0.44983457574245483+0.013293842460649208j)
#       converged: True
#            flag: converged
#  function_calls: 6
#      iterations: 5
#            root: (0.44813168087644856+0.013326699337448199j)
#       converged: True
#            flag: converged
#  function_calls: 6
#      iterations: 5
#            root: (0.4464357541122939+0.013359476002325843j)

# %% [markdown]
# ## Plot

# %%
str1 = f'Scaling/Flow-VA-Scaling-gr-MCI.pkl'
str2 = f'Scaling/Flow-VA-Scaling-gr-VA-MCI.pkl'
str3 = f'Scaling/Flow-VA-Scaling-gr-r2-MCI.pkl'

with open(str1, 'rb') as f:
    complex_freqs_MCI_1k1_Kep_uu = pickle.load(f)

with open(str2, 'rb') as f:
    VA_N_arr_up = pickle.load(f)
    
with open(str3, 'rb') as f:
    R_arr = pickle.load(f)

# %%
ii = np.where(complex_freqs_MCI_1k1_Kep_uu.imag > 0)
pos = np.zeros(np.shape(complex_freqs_MCI_1k1_Kep_uu), dtype = 'complex')
pos[ii[:]] = complex_freqs_MCI_1k1_Kep_uu[ii[:]]

print(pos)
###################### Growth Rate
fig, ax = plt.subplots(figsize=(5,5.5))
contour = plt.contourf(VA_N_arr_up, q_arr, np.transpose(pos.imag), levels=7, cmap = 'plasma')
contours = plt.contour(VA_N_arr_up, q_arr, np.transpose(pos.imag), levels=7, colors='black', linewidths=0.8)
plt.clabel(contours, inline=True, fontsize=8)
ax.set_xlabel(r'$V_A/\left(r_1\Omega_0\right)$')
# ax.set_ylabel(r'\textbf{Radially Averaged Vorticity Ratio} $\mathbf{\left<\nabla \times v \right>}$')

# Add a small colorbar at the top right
# cax = fig.add_axes([0.3, .92, 0.6, 0.02])   # [left, bottom, width, height]
cax = fig.add_axes([0.1, .95, 0.8, 0.02])
cbar = fig.colorbar(contour, cax=cax, orientation="horizontal")
cbar.ax.set_ylabel(r'$\gamma/\Omega_0$', labelpad=17.5, rotation=0, va='center')

# plt.savefig(f'Scaling/Flow-VA-MCI.png', dpi = 400, bbox_inches = 'tight')
# plt.savefig(f'Scaling/Flow-VA-MCI.svg', dpi = 400, bbox_inches = 'tight', format = 'svg')
plt.show()
# Out:
# [[0.3097527 +1.93152738e-02j 0.30749872+1.94126885e-02j
#   0.3052476 +1.95106673e-02j ... 0.14873153+2.01616765e-02j
#   0.14704305+1.96094538e-02j 0.14533651+1.90377979e-02j]
#  [0.31328369+2.10644240e-02j 0.31105447+2.11666269e-02j
#   0.30882845+2.12693166e-02j ... 0.15574916+2.08357510e-02j
#   0.15409383+2.02213700e-02j 0.15241618+1.95891758e-02j]
#  [0.3169315 +2.27469155e-02j 0.31472738+2.28528893e-02j
#   0.31252675+2.29592555e-02j ... 0.16284972+2.14230871e-02j
#   0.16122813+2.07478344e-02j 0.15957955+2.00564209e-02j]
#  ...
#  [0.52290803+8.83294152e-18j 0.52290504+1.49452772e-15j
#   0.52291002+2.47196522e-15j ... 0.51531312+3.57900842e-02j
#   0.51484354+3.60370958e-02j 0.51437813+3.62782144e-02j]
#  [0.        +0.00000000e+00j 0.        +0.00000000e+00j
#   0.51168501+1.07561219e-15j ... 0.51609683+2.67361741e-02j
#   0.51563416+2.71551873e-02j 0.51517562+2.75610402e-02j]
#  [0.        +0.00000000e+00j 0.50157299+6.86264953e-18j
#   0.        +0.00000000e+00j ... 0.51675325+3.35464145e-03j
#   0.51629571+6.22237691e-03j 0.51584225+8.10846651e-03j]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 8
#       6 ###################### Growth Rate
#       7 fig, ax = plt.subplots(figsize=(5,5.5))
# ----> 8 contour = plt.contourf(VA_N_arr_up, q_arr, np.transpose(pos.imag), levels=7, cmap = 'plasma')
#       9 contours = plt.contour(VA_N_arr_up, q_arr, np.transpose(pos.imag), levels=7, colors='black', linewidths=0.8)
#      10 plt.clabel(contours, inline=True, fontsize=8)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:3179, in contourf(data, *args, **kwargs)
#    3177 @_copy_docstring_and_deprecators(Axes.contourf)
#    3178 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 3179     __ret = gca().contourf(
#    3180         *args, **({"data": data} if data is not None else {}), **kwargs
#    3181     )
#    3182     if __ret._A is not None:  # type: ignore[attr-defined]
#    3183         sci(__ret)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_axes.py:6791, in Axes.contourf(self, *args, **kwargs)
#    6780 """
#    6781 Plot filled contours.
#    6782
#    (...)
#    6788 %(contour_doc)s
#    6789 """
#    6790 kwargs['filled'] = True
# -> 6791 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6792 self._request_autoscale_view()
#    6793 return contours
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\contour.py:701, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     697 if self.negative_linestyles is None:
#     698     self.negative_linestyles = \
#     699         mpl.rcParams['contour.negative_linestyle']
# --> 701 kwargs = self._process_args(*args, **kwargs)
#     702 self._process_levels()
#     704 self._extend_min = self.extend in ['min', 'both']
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\contour.py:1319, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1316         corner_mask = mpl.rcParams['contour.corner_mask']
#    1317 self._corner_mask = corner_mask
# -> 1319 x, y, z = self._contour_args(args, kwargs)
#    1321 contour_generator = contourpy.contour_generator(
#    1322     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1323     line_type=contourpy.LineType.SeparateCode,
#    1324     fill_type=contourpy.FillType.OuterCode,
#    1325     chunk_size=self.nchunk)
#    1327 t = self.get_transform()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\contour.py:1359, in QuadContourSet._contour_args(self, args, kwargs)
#    1357 elif 2 < nargs <= 4:
#    1358     x, y, z_orig, *args = args
# -> 1359     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1361 else:
#    1362     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\contour.py:1401, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1398         raise TypeError(f"Length of x ({nx}) must match number of "
#    1399                         f"columns in z ({Nx})")
#    1400     if ny != Ny:
# -> 1401         raise TypeError(f"Length of y ({ny}) must match number of "
#    1402                         f"rows in z ({Ny})")
#    1403     x, y = np.meshgrid(x, y)
#    1404 elif x.ndim == 2:
#
# TypeError: Length of y (601) must match number of rows in z (84)

# %%
ii = np.where(complex_freqs_MCI_1k1_Kep_uu.imag > 0)
pos = np.zeros(np.shape(complex_freqs_MCI_1k1_Kep_uu), dtype = 'complex')
pos[ii[:]] = complex_freqs_MCI_1k1_Kep_uu[ii[:]]

# print(pos)
###################### Growth Rate
fig, ax = plt.subplots(figsize=(5,5.5))
contour = plt.contourf(VA_N_arr_up, np.abs(R_arr), np.transpose(pos.imag), levels=7, cmap = 'plasma')
contours = plt.contour(VA_N_arr_up, np.abs(R_arr), np.transpose(pos.imag), levels=7, colors='black', linewidths=0.8)
plt.clabel(contours, inline=True, fontsize=8)
ax.set_xlabel(r'$\mathbf{V_A/\left(r_1\Omega_0\right)}$', fontsize = 15)
ax.set_ylabel(r"$\mathbf{\left<\Gamma'\right>_r/\left<\Gamma\right>_r}$", fontsize = 15)
# ax.set_ylabel(r'\textbf{Radially Averaged Vorticity Ratio}', fontsize = 15)

# Add a small colorbar at the top right
# cax = fig.add_axes([0.3, .92, 0.6, 0.02])   # [left, bottom, width, height]
cax = fig.add_axes([0.1, .95, 0.8, 0.02])
cbar = fig.colorbar(contour, cax=cax, orientation="horizontal")
cbar.ax.set_ylabel(r'$\mathbf{\gamma/\Omega_0}$', labelpad=17.5, rotation=0, va='center', fontsize = 14)

# plt.savefig(f'Scaling/Flow-VA-MCI.png', dpi = 400, bbox_inches = 'tight')
# plt.savefig(f'Scaling/Flow-VA-MCI.svg', dpi = 400, bbox_inches = 'tight', format = 'svg')
# plt.savefig(f'Scaling/Flow-VA-MCI.pdf', dpi = 400, bbox_inches = 'tight')
# plt.savefig(f'Scaling/Flow-VA-MCI-Vorticity-Ratio.pdf', dpi = 400, bbox_inches = 'tight')

plt.show()

# %%
ii = np.where(complex_freqs_MCI_1k1_Kep_uu.imag > 0)
pos = np.zeros(np.shape(complex_freqs_MCI_1k1_Kep_uu), dtype = 'complex')
pos[ii[:]] = complex_freqs_MCI_1k1_Kep_uu[ii[:]]

# print(pos)
###################### Growth Rate
fig, ax = plt.subplots(figsize=(5,5.5))
contour = plt.contourf(VA_N_arr_up, np.abs(v_arr/W_arr), np.transpose(pos.imag), levels=7, cmap = 'plasma')
contours = plt.contour(VA_N_arr_up, np.abs(v_arr/W_arr), np.transpose(pos.imag), levels=7, colors='black', linewidths=0.8)
plt.clabel(contours, inline=True, fontsize=8)
ax.set_xlabel(r'$\mathbf{V_A/\left(r_1\Omega_0\right)}$', fontsize = 15)
ax.set_ylabel(r"$\mathbf{\left<\Gamma\right>_r/\left<\Omega\right>_r}$", fontsize = 15)
# ax.set_ylabel(r'\textbf{Radially Averaged Vorticity Ratio}', fontsize = 15)

# Add a small colorbar at the top right
# cax = fig.add_axes([0.3, .92, 0.6, 0.02])   # [left, bottom, width, height]
cax = fig.add_axes([0.1, .95, 0.8, 0.02])
cbar = fig.colorbar(contour, cax=cax, orientation="horizontal")
cbar.ax.set_ylabel(r'$\mathbf{\gamma/\Omega_0}$', labelpad=17.5, rotation=0, va='center', fontsize = 14)

plt.show()
# plt.savefig(f'Scaling/Flow-VA-MCI.png', dpi = 400, bbox_inches = 'tight')
# plt.savefig(f'Scaling/Flow-VA-MCI.svg', dpi = 400, bbox_inches = 'tight', format = 'svg')
# plt.savefig(f'Scaling/Flow-VA-MCI.pdf', dpi = 400, bbox_inches = 'tight')
# plt.savefig(f'Scaling/Flow-VA-MCI-Vorticity-Ratio.pdf', dpi = 400, bbox_inches = 'tight')

# %%
ii = np.where(complex_freqs_MCI_1k1_Kep_uu.imag > 0)
pos = np.zeros(np.shape(complex_freqs_MCI_1k1_Kep_uu), dtype = 'complex')
pos[ii[:]] = complex_freqs_MCI_1k1_Kep_uu[ii[:]]

# print(pos)
###################### Growth Rate
fig, ax = plt.subplots(figsize=(5,5.5))
contour = plt.contourf(VA_N_arr_up, np.abs(vp_arr/W_arr), np.transpose(pos.imag), levels=7, cmap = 'plasma')
contours = plt.contour(VA_N_arr_up, np.abs(vp_arr/W_arr), np.transpose(pos.imag), levels=7, colors='black', linewidths=0.8)
plt.clabel(contours, inline=True, fontsize=8)
ax.set_xlabel(r'$\mathbf{V_A/\left(r_1\Omega_0\right)}$', fontsize = 15)
ax.set_ylabel(r"$\mathbf{\left<\Gamma'\right>_r/\left<\Omega\right>_r}$", fontsize = 15)
# ax.set_ylabel(r'\textbf{Radially Averaged Vorticity Ratio}', fontsize = 15)

# Add a small colorbar at the top right
# cax = fig.add_axes([0.3, .92, 0.6, 0.02])   # [left, bottom, width, height]
cax = fig.add_axes([0.1, .95, 0.8, 0.02])
cbar = fig.colorbar(contour, cax=cax, orientation="horizontal")
cbar.ax.set_ylabel(r'$\mathbf{\gamma/\Omega_0}$', labelpad=17.5, rotation=0, va='center', fontsize = 14)

plt.show()
# plt.savefig(f'Scaling/Flow-VA-MCI.png', dpi = 400, bbox_inches = 'tight')
# plt.savefig(f'Scaling/Flow-VA-MCI.svg', dpi = 400, bbox_inches = 'tight', format = 'svg')
# plt.savefig(f'Scaling/Flow-VA-MCI.pdf', dpi = 400, bbox_inches = 'tight')
# plt.savefig(f'Scaling/Flow-VA-MCI-Vorticity-Ratio.pdf', dpi = 400, bbox_inches = 'tight')

# %%
ii = np.where(complex_freqs_MCI_1k1_Kep_uu.imag > 0)
pos = np.zeros(np.shape(complex_freqs_MCI_1k1_Kep_uu), dtype = 'complex')
pos[ii[:]] = complex_freqs_MCI_1k1_Kep_uu[ii[:]]

# print(pos)
###################### Growth Rate
fig, ax = plt.subplots(figsize=(5,5.5))
contour = plt.contourf(VA_N_arr_up, np.abs(v_arr), np.transpose(pos.imag), levels=7, cmap = 'plasma')
contours = plt.contour(VA_N_arr_up, np.abs(v_arr), np.transpose(pos.imag), levels=7, colors='black', linewidths=0.8)
plt.clabel(contours, inline=True, fontsize=8)
ax.set_xlabel(r'$\mathbf{V_A/\left(r_1\Omega_0\right)}$', fontsize = 15)
# ax.set_ylabel(r'\textbf{Radially Averaged Vorticity} $\mathbf{\left<\left(\nabla \times v\right)_{\hat{z}} \right>}$', fontsize = 15)
ax.set_ylabel(r'$\mathbf{\left<\Gamma\right>_r}$', fontsize = 15)

# Add a small colorbar at the top right
# cax = fig.add_axes([0.3, .92, 0.6, 0.02])   # [left, bottom, width, height]
cax = fig.add_axes([0.1, .95, 0.8, 0.02])
cbar = fig.colorbar(contour, cax=cax, orientation="horizontal")
cbar.ax.set_ylabel(r'$\mathbf{\gamma/\Omega_0}$', labelpad=17.5, rotation=0, va='center', fontsize = 14)

# plt.savefig(f'Scaling/Flow-VA-MCI-Vorticity.png', dpi = 400, bbox_inches = 'tight')
# plt.savefig(f'Scaling/Flow-VA-MCI-Vorticity.pdf', dpi = 400, bbox_inches = 'tight')

plt.show()

# %%
ii = np.where(complex_freqs_MCI_1k1_Kep_uu.imag > 0)
pos = np.zeros(np.shape(complex_freqs_MCI_1k1_Kep_uu), dtype = 'complex')
pos[ii[:]] = complex_freqs_MCI_1k1_Kep_uu[ii[:]]

# print(pos)
###################### Growth Rate
fig, ax = plt.subplots(figsize=(5,5.5))
contour = plt.contourf(VA_N_arr_up, np.abs(vp_arr), np.transpose(pos.imag), levels=7, cmap = 'plasma')
contours = plt.contour(VA_N_arr_up, np.abs(vp_arr), np.transpose(pos.imag), levels=7, colors='black', linewidths=0.8)
plt.clabel(contours, inline=True, fontsize=8)
ax.set_xlabel(r'$V_A/\left(r_1\Omega_0\right)$')
# ax.set_ylabel(r'\textbf{Radially Averaged Vorticity Gradient} $\mathbf{\left<\nabla\left(\nabla \times v\right)_{\hat{z}} \right>}$', fontsize = 15)
ax.set_ylabel(r"$\mathbf{\left<\Gamma'\right>_r}$", fontsize = 15)

# Add a small colorbar at the top right
# cax = fig.add_axes([0.3, .92, 0.6, 0.02])   # [left, bottom, width, height]
cax = fig.add_axes([0.1, .95, 0.8, 0.02])
cbar = fig.colorbar(contour, cax=cax, orientation="horizontal")
cbar.ax.set_ylabel(r'$\mathbf{\gamma/\Omega_0}$', labelpad=17.5, rotation=0, va='center', fontsize = 14)

# plt.savefig(f'Scaling/Flow-VA-MCI-Vorticity-Gradient.png', dpi = 400, bbox_inches = 'tight')
# plt.savefig(f'Scaling/Flow-VA-MCI-Vorticity-Gradient.pdf', dpi = 400, bbox_inches = 'tight')

plt.show()

# %% [markdown]
# # Dump

# %%
# str1 = f'Scaling/Flow-VA-Scaling-gr-MCI.pkl'
# str2 = f'Scaling/Flow-VA-Scaling-gr-VA-MCI.pkl'
# str3 = f'Scaling/Flow-VA-Scaling-gr-r2-MCI.pkl'

# with open(str1, 'wb') as f:
#     pickle.dump(complex_freqs_MCI_1k1_Kep_uu, f)

# with open(str2, 'wb') as f:
#     pickle.dump(VA_N_arr_up, f)
    
# with open(str3, 'wb') as f:
#     pickle.dump(R_arr, f)
